# %%
# load the daily data, then calculate the value of it 

#df['value_ema_1_beta_99'] = df['diff_ema_1'].shift(-1).fillna(0) + \
#0.99 * df['value_ema_1_beta_99'].shift(-1).fillna(0)

# %%
import pandas as pd
import numpy as np

df = pd.read_json('../data/AAPL/data')

# %%
df.tail()
# Out:
#                timestamp        open        high         low       close  \
# 2512 2022-01-20 14:30:00  166.979996  169.679993  164.179993  164.509995
# 2513 2022-01-21 14:30:00  164.419998  166.330002  162.300003  162.410004
# 2514 2022-01-24 14:30:00  160.020004  162.300003  154.699997  161.619995
# 2515 2022-01-25 14:30:00  158.979996  162.759995  157.020004  159.779999
# 2516 2022-01-26 14:30:00  163.500000  164.389999  157.820007  159.690002
#
#          volumn
# 2512   91420500
# 2513  122501300
# 2514  162706700
# 2515  115798400
# 2516  107740600

# %%
df['date']=pd.to_datetime(df['timestamp']).apply(lambda x: x.date())
df['time']=pd.to_datetime(df['timestamp'])

# %%
df.tail()
# Out:
#                timestamp        open        high         low       close  \
# 2512 2022-01-20 14:30:00  166.979996  169.679993  164.179993  164.509995
# 2513 2022-01-21 14:30:00  164.419998  166.330002  162.300003  162.410004
# 2514 2022-01-24 14:30:00  160.020004  162.300003  154.699997  161.619995
# 2515 2022-01-25 14:30:00  158.979996  162.759995  157.020004  159.779999
# 2516 2022-01-26 14:30:00  163.500000  164.389999  157.820007  159.690002
#
#          volumn        date                time
# 2512   91420500  2022-01-20 2022-01-20 14:30:00
# 2513  122501300  2022-01-21 2022-01-21 14:30:00
# 2514  162706700  2022-01-24 2022-01-24 14:30:00
# 2515  115798400  2022-01-25 2022-01-25 14:30:00
# 2516  107740600  2022-01-26 2022-01-26 14:30:00

# %%
df['close_log'] = np.log(df['close'])
df['close_log_diff']=df['close_log'].diff().fillna(0)

# %%
df.head()
# Out:
#             timestamp       open       high        low      close     volumn  \
# 0 2012-01-27 14:30:00  15.869286  16.017143  15.848929  15.974286  299709200
# 1 2012-01-30 14:30:00  15.918214  16.210714  15.906786  16.178928  379341200
# 2 2012-01-31 14:30:00  16.271070  16.365713  16.181070  16.302856  391683600
# 3 2012-02-01 14:30:00  16.371786  16.392500  16.269644  16.292500  270046000
# 4 2012-02-02 14:30:00  16.282143  16.327499  16.213572  16.254286  186796400
#
#          date                time  close_log  close_log_diff
# 0  2012-01-27 2012-01-27 14:30:00   2.770980        0.000000
# 1  2012-01-30 2012-01-30 14:30:00   2.783710        0.012729
# 2  2012-01-31 2012-01-31 14:30:00   2.791340        0.007631
# 3  2012-02-01 2012-02-01 14:30:00   2.790705       -0.000635
# 4  2012-02-02 2012-02-02 14:30:00   2.788357       -0.002348

# %%
df['value']=0
for i in range(20):
    df['value']=df['close_log_diff'].shift(-1).fillna(0)+0.9*df['value'].shift(-1).fillna(0)

# %%
df.tail(20)
# Out:
#                timestamp        open        high         low       close  \
# 2497 2021-12-29 14:30:00  179.330002  180.630005  178.139999  179.380005
# 2498 2021-12-30 14:30:00  179.470001  180.570007  178.089996  178.199997
# 2499 2021-12-31 14:30:00  178.089996  179.229996  177.259995  177.570007
# 2500 2022-01-03 14:30:00  177.830002  182.880005  177.710007  182.009995
# 2501 2022-01-04 14:30:00  182.630005  182.940002  179.119995  179.699997
# 2502 2022-01-05 14:30:00  179.610001  180.169998  174.639999  174.919998
# 2503 2022-01-06 14:30:00  172.699997  175.300003  171.639999  172.000000
# 2504 2022-01-07 14:30:00  172.889999  174.139999  171.029999  172.169998
# 2505 2022-01-10 14:30:00  169.080002  172.500000  168.169998  172.190002
# 2506 2022-01-11 14:30:00  172.320007  175.179993  170.820007  175.080002
# 2507 2022-01-12 14:30:00  176.119995  177.179993  174.820007  175.529999
# 2508 2022-01-13 14:30:00  175.779999  176.619995  171.789993  172.190002
# ...

# %%
def gradeToNum(grade):
    return {
        'Buy':1,
        'Overweight':2,
        'Outperform':2,
        'Sell':5,
        'Neutral':3,
        'Hold':3,
        'Equal-Weight':3,
        'Underweight':4,
        'Market Outperform':2,
        'Market Perform':3,
        'Strong Buy': 0,
        'Peer Perform': 3,
        'Underperform':4,
        'Reduce':4,
        'Sector Weight':3,
        'Negative':4,
        'Perform':3,
        'Positive':2,
        'Sector Perform':3,
        'Equal-weight':3,
        'Long-Term Buy':2,
        'Long-term Buy':2,
        'Sector Outperform':2,
        '':3
    }[grade]

# %%
df2 = pd.read_json('../data/AAPL/updown')
df2['toGradeNum']=df2['toGrade'].apply(gradeToNum)

# %%
df2['date']=pd.to_datetime(df2['epochGradeDate'].astype('timedelta64[s]')).apply(lambda x: x.date())
df2['time']=pd.to_datetime(df2['epochGradeDate'].astype('timedelta64[s]'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-664cb3c7a0c7> in <module>
# ----> 1 df2['date']=pd.to_datetime(df2['epochGradeDate'].astype('timedelta64[s]')).apply(lambda x: x.date())
#       2 df2['time']=pd.to_datetime(df2['epochGradeDate'].astype('timedelta64[s]'))
#
# ~/.local/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049             result = arg.map(cache_array)
#    1050         else:
# -> 1051             values = convert_listlike(arg._values, format)
#    1052             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
df2.tail()
# Out:
#     action  epochGradeDate               firm fromGrade     toGrade  \
# 816   main      1331713260  Canaccord Genuity                   Buy
# 817   main      1331705580     Morgan Stanley            Overweight
# 818   main      1331618880          Jefferies                   Buy
# 819   main      1331191980     FBN Securities            Outperform
# 820   main      1328775420  Canaccord Genuity                   Buy
#
#      toGradeNum        date                time
# 816           1  2012-03-14 2012-03-14 08:21:00
# 817           2  2012-03-14 2012-03-14 06:13:00
# 818           1  2012-03-13 2012-03-13 06:08:00
# 819           2  2012-03-08 2012-03-08 07:33:00
# 820           1  2012-02-09 2012-02-09 08:17:00

# %%
df2 = df2.iloc[::-1]

# %%
df2.head()
# Out:
#     action  epochGradeDate               firm fromGrade     toGrade  \
# 820   main      1328775420  Canaccord Genuity                   Buy
# 819   main      1331191980     FBN Securities            Outperform
# 818   main      1331618880          Jefferies                   Buy
# 817   main      1331705580     Morgan Stanley            Overweight
# 816   main      1331713260  Canaccord Genuity                   Buy
#
#      toGradeNum        date                time
# 820           1  2012-02-09 2012-02-09 08:17:00
# 819           2  2012-03-08 2012-03-08 07:33:00
# 818           1  2012-03-13 2012-03-13 06:08:00
# 817           2  2012-03-14 2012-03-14 06:13:00
# 816           1  2012-03-14 2012-03-14 08:21:00

# %%
grouped = df2.groupby('firm')

# %%
alist = [grouped.get_group(x) for x in grouped.groups]

# %%
alist[9]
# Out:
#     action  epochGradeDate           firm fromGrade  toGrade  toGradeNum  \
# 798   down      1333954800  BTIG Research            Neutral           3
# 687     up      1363247623  BTIG Research   Neutral      Buy           1
# 451   main      1460012964  BTIG Research                Buy           1
# 449   main      1461711804  BTIG Research                Buy           1
# 426   main      1469593715  BTIG Research                Buy           1
# 395   main      1473926891  BTIG Research                Buy           1
# 383   main      1600853202  BTIG Research       Buy      Buy           1
#
#            date                time
# 798  2012-04-09 2012-04-09 07:00:00
# 687  2013-03-14 2013-03-14 07:53:43
# 451  2016-04-07 2016-04-07 07:09:24
# 449  2016-04-26 2016-04-26 23:03:24
# 426  2016-07-27 2016-07-27 04:28:35
# 395  2016-09-15 2016-09-15 08:08:11
# 383  2020-09-23 2020-09-23 09:26:42

# %%
i = 0
for df_updown in alist:
    print(i)
    companyName = df_updown['firm'].iloc[0]
    df_updown.rename(columns={'toGradeNum': companyName}, inplace=True)
    df = pd.merge_asof(df, df_updown[['time',companyName]].sort_values(by=['time']), on='time')
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# /home/ken/.local/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/ken/.local/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/ken/.local/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.tail()
# Out:
#            close        high         low        open           timestamp  \
# 2512  164.509995  169.679993  164.179993  166.979996 2022-01-20 14:30:00
# 2513  162.410004  166.330002  162.300003  164.419998 2022-01-21 14:30:00
# 2514  161.619995  162.300003  154.699997  160.020004 2022-01-24 14:30:00
# 2515  159.779999  162.759995  157.020004  158.979996 2022-01-25 14:30:00
# 2516  159.690002  164.389999  157.820007  163.500000 2022-01-26 14:30:00
#
#          volumn        date                time  close_log  close_log_diff  \
# 2512   91420500  2022-01-20 2022-01-20 14:30:00   5.102971       -0.010401
# 2513  122501300  2022-01-21 2022-01-21 14:30:00   5.090124       -0.012847
# 2514  162706700  2022-01-24 2022-01-24 14:30:00   5.085248       -0.004876
# 2515  115798400  2022-01-25 2022-01-25 14:30:00   5.073798       -0.011450
# 2516  107740600  2022-01-26 2022-01-26 14:30:00   5.073234       -0.000563
#
#       ...  Stifel Nicolaus  Susquehanna  Telsey Advisory Group  \
# ...

# %%
df['close_log_diff'].autocorr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1e48f8cc4f93> in <module>
# ----> 1 df['close_log_diff'].autocorr()
#
# NameError: name 'df' is not defined

# %%
df.iloc[:, 10:].tail()
# Out:
#          value  ABG Sundal Collier  Ameriprise Financial  Argus  \
# 2512 -0.026921                 5.0                   1.0    1.0
# 2513 -0.015638                 5.0                   1.0    1.0
# 2514 -0.011957                 5.0                   1.0    1.0
# 2515 -0.000563                 5.0                   1.0    1.0
# 2516  0.000000                 5.0                   1.0    1.0
#
#       Argus Research  Atlantic Equities  Avondale Partners  B of A Securities  \
# 2512             1.0                4.0                2.0                1.0
# 2513             1.0                4.0                2.0                1.0
# 2514             1.0                4.0                2.0                1.0
# 2515             1.0                4.0                2.0                1.0
# 2516             1.0                4.0                2.0                1.0
#
#       BGC Financial  BMO Capital  ...  Stifel Nicolaus  Susquehanna  \
# ...

# %%
values = df.iloc[:, 10:].fillna(3).corr()

# %%
values
# Out:
#                                value  ABG Sundal Collier  \
# value                       1.000000            0.008916
# ABG Sundal Collier          0.008916            1.000000
# Ameriprise Financial       -0.096497           -0.147860
# Argus                      -0.063407           -0.461409
# Argus Research              0.004051           -0.975209
# Atlantic Equities           0.053443            0.778807
# Avondale Partners          -0.100899           -0.147315
# B of A Securities          -0.048644           -0.035835
# BGC Financial              -0.004239            0.114011
# BMO Capital                 0.120614            0.443462
# BTIG Research              -0.086310           -0.140138
# Baird                      -0.068257           -0.181835
# Bank of America            -0.028196            0.429792
# Bank oferica                0.108862           -0.057861
# Barclays                    0.158404            0.319519
# ...

# %%
values['value'].sort_values()
# Out:
# Piper Jaffray           -0.119546
# Cascend                 -0.109495
# Avondale Partners       -0.100899
# FBR Capital             -0.098502
# Daiwa Capital           -0.097340
# William Blair           -0.096664
# Ameriprise Financial    -0.096497
# Raymond James           -0.088915
# BTIG Research           -0.086310
# Evercore Partners       -0.082714
# Cantor Fitzgerald       -0.080683
# Mizuho                  -0.080587
# Susquehanna             -0.080557
# RBC Capital             -0.076008
# Janney Capital          -0.076008
# DA Davidson             -0.074635
# KeyBanc                 -0.073011
# Baird                   -0.068257
# Canaccord Genuity       -0.067792
# Argus                   -0.063407
# Cowen & Co.             -0.063154
# Stifel                  -0.060893
# Sterne Agee CRT         -0.059729
# CLSA                    -0.059590
# Drexel Hamilton         -0.058666
# Piper Sandler           -0.054328
# Pacific Crest           -0.052920
# ...
