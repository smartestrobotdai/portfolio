# %%
# idea:
# use 5 years data: 2016.1.1 - 2021.1.1 to train the model
# use 1 years data: 2020.1.1 - 2021.1.1 to find a good policy. 
# policy 1: choose the stock with maximum value, sell it when a) a stop loss/gain threshold is met.
# test it use 2021.1.1 to now.
import os
import pandas as pd
import json
from sklearn.linear_model import LinearRegression
import numpy as np

import matplotlib.pyplot as plt
from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRegressor
# Out:
# /home/ken/.local/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/ken/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ken/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.13.1-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ken/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/ken/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 2.20.2ubuntu2 is an invalid version and will not be supported in a future release
#   warnings.warn(

# %%
def get_meta(filename):
    f = open(filename)
    data = json.load(f)
    return data['currency'], data['regularMarketPrice'], data['regularMarketTime']

def get_change_rate(filename):
    f = open(filename)
    data = json.load(f)
    return data['regularMarketPrice'], data['regularMarketTime']

# %%
def get_exchange_dir(from_, to_):
  if from_ == 'USD' and to_ == 'SEK':
    return 'SEK=X'
  elif from_ == 'USD' and to_ == 'EUR':
    return 'EUR=X'
  elif from_ == 'EUR' and to_ == 'SEK':
    return 'EURSEK=X'

# %%
def convert_currency(df, path):
  currency, cur_price, cur_time = get_meta(os.path.join(path, 'meta'))
  if currency != 'SEK':
    print(currency)
    ex_dir = get_exchange_dir(currency, 'SEK')
    ex_data_file = os.path.join('../data/indicators/', ex_dir, 'data')
    ex_meta_file = os.path.join('../data/indicators/', ex_dir, 'meta')
    right = pd.read_json(ex_data_file).dropna()
    change_rate, timestamp = get_change_rate(ex_meta_file)
    right['time']=pd.to_datetime(right['timestamp'],unit='s')
    right['close_ex']=right['close']
    df = pd.merge_asof(df, right[['time', 'close_ex']], on='time')
    df['close']=df['close']*df['close_ex']
    df['high']=df['high']*df['close_ex']
    df['low']=df['low']*df['close_ex']
    df['open']=df['open']*df['close_ex']
  return df

# %%
def linear_regression(df, period):
  PERIOD=period
  df = df.dropna()
  df['close_log_error_' + str(period)]=0
  df['close_log_linear_' + str(period)]=df['close_log']

  for i in range(int(len(df)/PERIOD)):
      X = df['time'][i*PERIOD:(i+1)*PERIOD].astype(np.int64).values.reshape(-1, 1)  # iloc[:, 1] is the column of X
      Y = df['close_log'][i*PERIOD:(i+1)*PERIOD].values.reshape(-1, 1)  # df.iloc[:, 4] is the column of Y
      linear_regressor = LinearRegression()
      linear_regressor.fit(X, Y)
      X_next = df['time'][(i+1)*PERIOD:(i+2)*PERIOD].astype(np.int64).values.reshape(-1, 1)
      Y_pred = linear_regressor.predict(X_next)
      df['close_log_linear_' + str(PERIOD)].iloc[(i+1)*PERIOD: (i+2)*PERIOD] = Y_pred.reshape(-1,)

  df['close_log_error_' + str(PERIOD)] = df['close_log'] - df['close_log_linear_' + str(PERIOD)]
  return df

# %%
def add_value(df):
  df['value']=0
  for i in range(20):
    df['value']=df['open_log_diff'].shift(-1).fillna(0)+0.9*df['value'].shift(-1).fillna(0)
  return df

# %%
def add_diff(df):
  df['close_log'] = np.log(df['close'])
  df['close_log_diff']=df['close_log'].diff()
  df['close_log_diff_1']=df['close_log_diff'].shift(1)
  df['close_log_diff_2']=df['close_log_diff'].shift(2)
  df['low_log'] = np.log(df['low'])
  df['low_log_diff'] = df['low_log'] - df['close_log'].shift(1)
  df['open_log'] = np.log(df['open'])
  df['open_log_close_log_diff'] = df['open_log'] - df['close_log'].shift(1)
  df['high_log'] = np.log(df['high'])
  df['high_log_diff'] = df['high_log'] - df['close_log'].shift(1)
  return df.dropna()

# %%
def handle_stock(name):
  if (name[0] == '^'):
    path = os.path.join('../data/indicators', name)
  else:
    path = os.path.join('../data/stocks', name)
  df = pd.read_json(os.path.join(path, 'data'))
  df['time']=pd.to_datetime(df['timestamp'],unit='s')
  #df = convert_currency(df, path)
  df = add_diff(df)
  df = linear_regression(df, 253)
  df = linear_regression(df, 63)
  df = add_value(df)
  return df

# %%
df = handle_stock('AAPL')

# %%
df.plot(x='time', y=['close_log','close_log_linear_63', 'close_log_linear_253'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.tail()
# Out:
#                timestamp        open        high         low       close  \
# 2513 2022-02-14 14:30:00  167.369995  169.580002  166.559998  168.880005
# 2514 2022-02-15 14:30:00  170.970001  172.949997  170.250000  172.789993
# 2515 2022-02-16 14:30:00  171.850006  173.339996  170.050003  172.550003
# 2516 2022-02-17 14:30:00  171.029999  171.910004  168.470001  168.880005
# 2517 2022-02-18 17:58:15  169.820007  170.541306  166.720001  166.812103
#
#         volumn                time  close_log  close_log_diff  \
# 2513  86062800 2022-02-14 14:30:00   5.129188        0.001422
# 2514  64286300 2022-02-15 14:30:00   5.152077        0.022889
# 2515  61177400 2022-02-16 14:30:00   5.150687       -0.001390
# 2516  69387600 2022-02-17 14:30:00   5.129188       -0.021499
# 2517  40219976 2022-02-18 17:58:15   5.116868       -0.012320
#
#       close_log_diff_1  ...  low_log_diff  open_log  open_log_diff  high_log  \
# 2513         -0.020426  ...     -0.012411  5.120207      -0.007559  5.133325
# 2514          0.001422  ...      0.008080  5.141488       0.012300  5.153003
# 2515          0.022889  ...     -0.015984  5.146622      -0.005455  5.155255
# 2516         -0.001390  ...     -0.023929  5.141839      -0.008848  5.146971
# 2517         -0.021499  ...     -0.012873  5.134739       0.005551  5.138978
#
#       high_log_diff  close_log_error_253  close_log_linear_253  \
# 2513       0.005559            -0.597727              5.726915
# 2514       0.023814            -0.576939              5.729016
# 2515       0.003178            -0.580430              5.731117
# 2516      -0.003716            -0.604030              5.733218
# 2517       0.009789            -0.618755              5.735623
#
#       close_log_error_63  close_log_linear_63     value
# 2513            0.069584             5.059605 -0.004758
# 2514            0.092021             5.060056 -0.030718
# 2515            0.090181             5.060506 -0.032587
# 2516            0.068231             5.060957 -0.012320
# 2517            0.055395             5.061473  0.000000
#
# [5 rows x 22 columns]

# %%
rootdir = '../data/stocks'
stock_list = []

stock_list.append('^DJI')
stock_list.append('^OMX')

# %% [markdown]
# for subdir, dirs, files in os.walk(rootdir):
#   for dir in dirs:
#     obj =  {}
#     name = dir
#     stock_list.append(name)

# %%
def rename_dataframe(df, name):
  return df.rename(columns={'close_log': 'close_log_' + name,
                            'close_log_error_63': 'close_log_error_63_' + name,
                            'close_log_error_253': 'close_log_error_253_' + name,
                            'value': 'value_' + name,
                            'log': 'log_' + name,
                            'log_diff': 'log_diff_' + name,
                            'close_log_diff': 'close_log_diff_' + name,
                            'close_log_diff_1': 'close_log_diff_1_' + name,
                            'close_log_diff_2': 'close_log_diff_2_' + name,
                            'low_log_diff': 'low_log_diff_' + name,
                            'open_log_diff': 'open_log_diff_' + name,
                            'high_log_diff': 'high_log_diff_' + name,
                            'data': 'data_' + name,
                            'data_log': 'data_log_' + name,
                            'data_log_diff': 'data_log_diff_' + name})

# %%
name = stock_list[0]
df = handle_stock(name)
columns = ['time', 'close_log', 'close_log_error_63', 'close_log_error_253', 'value', 'close_log_diff', 'close_log_diff_1', 'close_log_diff_2', 'open_log_diff', 'low_log_diff', 'high_log_diff']
df = rename_dataframe(df[columns], name)

for i in range(1, len(stock_list)):
  name = stock_list[i]
  df1 = handle_stock(name)
  df1 = rename_dataframe(df1[columns], name)
  df = pd.merge_asof(df, df1, on='time')

# %%
df.head()
# Out:
#                  time  close_log_^DJI  close_log_error_63_^DJI  \
# 0 2012-02-24 14:30:00        9.471392                      0.0
# 1 2012-02-27 14:30:00        9.471281                      0.0
# 2 2012-02-28 14:30:00        9.473098                      0.0
# 3 2012-02-29 14:30:00        9.469011                      0.0
# 4 2012-03-01 14:30:00        9.471188                      0.0
#
#    close_log_error_253_^DJI  value_^DJI  close_log_diff_^DJI  \
# 0                       0.0    0.001675            -0.000134
# 1                       0.0    0.003635            -0.000111
# 2                       0.0    0.001572             0.001817
# 3                       0.0    0.005554            -0.004087
# 4                       0.0    0.003954             0.002177
#
#    close_log_diff_1_^DJI  close_log_diff_2_^DJI  open_log_diff_^DJI  \
# 0               0.003551              -0.002086           -0.000269
# 1              -0.000134               0.003551           -0.000140
# 2              -0.000111              -0.000134           -0.000367
# 3               0.001817              -0.000111            0.000023
# 4              -0.004087               0.001817            0.000017
#
#    low_log_diff_^DJI  ...  close_log_^OMX  close_log_error_63_^OMX  \
# 0          -0.002630  ...        7.003075                      0.0
# 1          -0.007760  ...        6.997203                      0.0
# 2          -0.002212  ...        7.005036                      0.0
# 3          -0.005819  ...        7.004664                      0.0
# 4          -0.000696  ...        7.007220                      0.0
#
#    close_log_error_253_^OMX  value_^OMX  close_log_diff_^OMX  \
# 0                       0.0   -0.004926             0.003497
# 1                       0.0    0.003347            -0.005872
# 2                       0.0   -0.005902             0.007833
# 3                       0.0   -0.007570            -0.000372
# 4                       0.0   -0.014480             0.002556
#
#    close_log_diff_1_^OMX  close_log_diff_2_^OMX  open_log_diff_^OMX  \
# 0               0.000100              -0.009408            0.003070
# 1               0.003497               0.000100           -0.004127
# 2              -0.005872               0.003497            0.002311
# 3               0.007833              -0.005872            0.001242
# 4              -0.000372               0.007833           -0.003373
#
#    low_log_diff_^OMX  high_log_diff_^OMX
# 0          -0.004334            0.005431
# 1          -0.016277           -0.002294
# 2          -0.000594            0.008096
# 3          -0.002671            0.006881
# 4          -0.008239            0.006442
#
# [5 rows x 21 columns]

# %%
def reorder(df):
  columns_indicator_value = list(filter(lambda c: 'value' in c and '^' in c, df.columns.tolist()))
  columns_stock_value = list(filter(lambda c: 'value' in c and '^' not in c, df.columns.tolist()))
  columns_non_value = list(filter(lambda c: 'value' not in c, df.columns.tolist()))
  df = df[columns_non_value + columns_stock_value + columns_indicator_value]
  return df

df = reorder(df)
df.head()
# Out:
#                  time  close_log_^DJI  close_log_error_63_^DJI  \
# 0 2012-02-24 14:30:00        9.471392                      0.0
# 1 2012-02-27 14:30:00        9.471281                      0.0
# 2 2012-02-28 14:30:00        9.473098                      0.0
# 3 2012-02-29 14:30:00        9.469011                      0.0
# 4 2012-03-01 14:30:00        9.471188                      0.0
#
#    close_log_error_253_^DJI  close_log_diff_^DJI  close_log_diff_1_^DJI  \
# 0                       0.0            -0.000134               0.003551
# 1                       0.0            -0.000111              -0.000134
# 2                       0.0             0.001817              -0.000111
# 3                       0.0            -0.004087               0.001817
# 4                       0.0             0.002177              -0.004087
#
#    close_log_diff_2_^DJI  open_log_diff_^DJI  low_log_diff_^DJI  \
# 0              -0.002086           -0.000269          -0.002630
# 1               0.003551           -0.000140          -0.007760
# 2              -0.000134           -0.000367          -0.002212
# 3              -0.000111            0.000023          -0.005819
# 4               0.001817            0.000017          -0.000696
#
#    high_log_diff_^DJI  ...  close_log_error_63_^OMX  close_log_error_253_^OMX  \
# 0            0.002241  ...                      0.0                       0.0
# 1            0.003427  ...                      0.0                       0.0
# 2            0.003077  ...                      0.0                       0.0
# 3            0.003886  ...                      0.0                       0.0
# 4            0.006204  ...                      0.0                       0.0
#
#    close_log_diff_^OMX  close_log_diff_1_^OMX  close_log_diff_2_^OMX  \
# 0             0.003497               0.000100              -0.009408
# 1            -0.005872               0.003497               0.000100
# 2             0.007833              -0.005872               0.003497
# 3            -0.000372               0.007833              -0.005872
# 4             0.002556              -0.000372               0.007833
#
#    open_log_diff_^OMX  low_log_diff_^OMX  high_log_diff_^OMX  value_^DJI  \
# 0            0.003070          -0.004334            0.005431    0.001675
# 1           -0.004127          -0.016277           -0.002294    0.003635
# 2            0.002311          -0.000594            0.008096    0.001572
# 3            0.001242          -0.002671            0.006881    0.005554
# 4           -0.003373          -0.008239            0.006442    0.003954
#
#    value_^OMX
# 0   -0.004926
# 1    0.003347
# 2   -0.005902
# 3   -0.007570
# 4   -0.014480
#
# [5 rows x 21 columns]

# %%
pd.options.display.max_rows = 4000
print(df.corr().iloc[:-len(stock_list), -2].sort_values())
# Out:
# close_log_error_63_^DJI    -0.148634
# close_log_error_253_^DJI   -0.115408
# close_log_^OMX             -0.076062
# close_log_error_253_^OMX   -0.061517
# close_log_^DJI             -0.060554
# low_log_diff_^DJI          -0.059797
# close_log_diff_^DJI        -0.053047
# open_log_diff_^OMX         -0.051980
# low_log_diff_^OMX          -0.048083
# close_log_diff_2_^DJI      -0.040380
# open_log_diff_^DJI         -0.020439
# close_log_diff_^OMX        -0.004162
# high_log_diff_^OMX         -0.001308
# close_log_diff_2_^OMX       0.006048
# high_log_diff_^DJI          0.009614
# close_log_diff_1_^DJI       0.029345
# close_log_error_63_^OMX     0.029422
# close_log_diff_1_^OMX       0.048557
# Name: value_^DJI, dtype: float64

# %%
#data = df[:-253].sample(frac=1).values
#X, y = data[:, 1:-len(stock_list)], data[:, -len(stock_list)]

# %%
#model = XGBRegressor()
#cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %%
#scores = absolute(scores)
#print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))

# %%
def load_indicator(name):
  path = os.path.join('../data/indicators', name)
  df = pd.read_json(os.path.join(path, 'data')).dropna()
  df['time']=pd.to_datetime(df['timestamp'],unit='s')
  return df

# %%
rootdir = '../data/indicators'
indicators_list = []
for subdir, dirs, files in os.walk(rootdir):
  for dir in dirs:
    name = dir
    if '^' not in name:
      indicators_list.append(name)

# %%
# CL=F: oil
# ZB=F: bond
# GC=F: gold
indicators_list
# Out:
# ['EURSEK=X', 'CL=F', 'EUR=X', 'ZB=F', 'GC=F', 'SEK=X']

# %%
def printna(df):
  print(df[df.isna().any(axis=1)])

# %%
for i in range(len(indicators_list)):
  name = indicators_list[i]
  print('merging name:' + name)
  df1 = load_indicator(name)
  df1 = df1.dropna()
  df1 = add_diff(df1)
  df1 = linear_regression(df1, 63)
  df1 = rename_dataframe(df1[['time', 'close_log', 'close_log_error_63', 'close_log_diff', 'close_log_diff_1', 'close_log_diff_2']], name)
  df = pd.merge_asof(df, df1, on='time')
# Out:
# merging name:EURSEK=X
# merging name:CL=F
# /home/ken/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ken/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ken/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# merging name:EUR=X
# merging name:ZB=F
# merging name:GC=F
# merging name:SEK=X

# %%
df.head()
# Out:
#                  time  close_log_^DJI  close_log_error_63_^DJI  \
# 0 2012-02-24 14:30:00        9.471392                      0.0
# 1 2012-02-27 14:30:00        9.471281                      0.0
# 2 2012-02-28 14:30:00        9.473098                      0.0
# 3 2012-02-29 14:30:00        9.469011                      0.0
# 4 2012-03-01 14:30:00        9.471188                      0.0
#
#    close_log_error_253_^DJI  close_log_diff_^DJI  close_log_diff_1_^DJI  \
# 0                       0.0            -0.000134               0.003551
# 1                       0.0            -0.000111              -0.000134
# 2                       0.0             0.001817              -0.000111
# 3                       0.0            -0.004087               0.001817
# 4                       0.0             0.002177              -0.004087
#
#    close_log_diff_2_^DJI  open_log_diff_^DJI  low_log_diff_^DJI  \
# 0              -0.002086           -0.000269          -0.002630
# 1               0.003551           -0.000140          -0.007760
# 2              -0.000134           -0.000367          -0.002212
# 3              -0.000111            0.000023          -0.005819
# 4               0.001817            0.000017          -0.000696
#
#    high_log_diff_^DJI  ...  close_log_GC=F  close_log_error_63_GC=F  \
# 0            0.002241  ...        7.481612                      0.0
# 1            0.003427  ...        7.480767                      0.0
# 2            0.003077  ...        7.488294                      0.0
# 3            0.003886  ...        7.444190                      0.0
# 4            0.006204  ...        7.450719                      0.0
#
#    close_log_diff_GC=F  close_log_diff_1_GC=F  close_log_diff_2_GC=F  \
# 0            -0.005506               0.008383               0.007315
# 1            -0.000845              -0.005506               0.008383
# 2             0.007527              -0.000845              -0.005506
# 3            -0.044103               0.007527              -0.000845
# 4             0.006529              -0.044103               0.007527
#
#    close_log_SEK=X  close_log_error_63_SEK=X  close_log_diff_SEK=X  \
# 0         1.889007                       0.0             -0.006376
# 1         1.878717                       0.0             -0.010290
# 2         1.885128                       0.0              0.006412
# 3         1.878533                       0.0             -0.006595
# 4         1.889733                       0.0              0.011199
#
#    close_log_diff_1_SEK=X  close_log_diff_2_SEK=X
# 0                0.001429               -0.003905
# 1               -0.006376                0.001429
# 2               -0.010290               -0.006376
# 3                0.006412               -0.010290
# 4               -0.006595                0.006412
#
# [5 rows x 51 columns]

# %%
df = reorder(df)

# %%
df.head()
# Out:
#                  time  close_log_^DJI  close_log_error_63_^DJI  \
# 0 2012-02-24 14:30:00        9.471392                      0.0
# 1 2012-02-27 14:30:00        9.471281                      0.0
# 2 2012-02-28 14:30:00        9.473098                      0.0
# 3 2012-02-29 14:30:00        9.469011                      0.0
# 4 2012-03-01 14:30:00        9.471188                      0.0
#
#    close_log_error_253_^DJI  close_log_diff_^DJI  close_log_diff_1_^DJI  \
# 0                       0.0            -0.000134               0.003551
# 1                       0.0            -0.000111              -0.000134
# 2                       0.0             0.001817              -0.000111
# 3                       0.0            -0.004087               0.001817
# 4                       0.0             0.002177              -0.004087
#
#    close_log_diff_2_^DJI  open_log_diff_^DJI  low_log_diff_^DJI  \
# 0              -0.002086           -0.000269          -0.002630
# 1               0.003551           -0.000140          -0.007760
# 2              -0.000134           -0.000367          -0.002212
# 3              -0.000111            0.000023          -0.005819
# 4               0.001817            0.000017          -0.000696
#
#    high_log_diff_^DJI  ...  close_log_diff_GC=F  close_log_diff_1_GC=F  \
# 0            0.002241  ...            -0.005506               0.008383
# 1            0.003427  ...            -0.000845              -0.005506
# 2            0.003077  ...             0.007527              -0.000845
# 3            0.003886  ...            -0.044103               0.007527
# 4            0.006204  ...             0.006529              -0.044103
#
#    close_log_diff_2_GC=F  close_log_SEK=X  close_log_error_63_SEK=X  \
# 0               0.007315         1.889007                       0.0
# 1               0.008383         1.878717                       0.0
# 2              -0.005506         1.885128                       0.0
# 3              -0.000845         1.878533                       0.0
# 4               0.007527         1.889733                       0.0
#
#    close_log_diff_SEK=X  close_log_diff_1_SEK=X  close_log_diff_2_SEK=X  \
# 0             -0.006376                0.001429               -0.003905
# 1             -0.010290               -0.006376                0.001429
# 2              0.006412               -0.010290               -0.006376
# 3             -0.006595                0.006412               -0.010290
# 4              0.011199               -0.006595                0.006412
#
#    value_^DJI  value_^OMX
# 0    0.001675   -0.004926
# 1    0.003635    0.003347
# 2    0.001572   -0.005902
# 3    0.005554   -0.007570
# 4    0.003954   -0.014480
#
# [5 rows x 51 columns]

# %%
pd.options.display.max_rows = 4000
print(df.corr().iloc[:-len(stock_list), -2].sort_values())
# Out:
# close_log_error_63_^DJI       -0.148634
# close_log_error_63_GC=F       -0.122817
# close_log_error_253_^DJI      -0.115408
# close_log_CL=F                -0.088852
# close_log_^OMX                -0.076062
# close_log_error_253_^OMX      -0.061517
# close_log_^DJI                -0.060554
# low_log_diff_^DJI             -0.059797
# close_log_diff_^DJI           -0.053047
# open_log_diff_^OMX            -0.051980
# low_log_diff_^OMX             -0.048083
# close_log_diff_2_^DJI         -0.040380
# open_log_diff_^DJI            -0.020439
# close_log_EUR=X               -0.020054
# close_log_diff_1_ZB=F         -0.018529
# close_log_diff_2_GC=F         -0.014688
# close_log_SEK=X               -0.012656
# close_log_diff_2_ZB=F         -0.006098
# close_log_diff_^OMX           -0.004162
# high_log_diff_^OMX            -0.001308
# close_log_EURSEK=X            -0.001024
# close_log_diff_2_^OMX          0.006048
# close_log_error_63_CL=F        0.006197
# close_log_diff_ZB=F            0.007702
# high_log_diff_^DJI             0.009614
# close_log_diff_EURSEK=X        0.011497
# close_log_diff_1_GC=F          0.018313
# close_log_error_63_EURSEK=X    0.024685
# close_log_error_63_ZB=F        0.026780
# close_log_diff_EUR=X           0.027533
# close_log_diff_1_^DJI          0.029345
# close_log_error_63_^OMX        0.029422
# close_log_diff_GC=F            0.031997
# close_log_diff_1_EURSEK=X      0.035178
# close_log_diff_CL=F            0.036518
# close_log_diff_SEK=X           0.037315
# close_log_error_63_EUR=X       0.039400
# close_log_GC=F                 0.040658
# close_log_diff_2_EURSEK=X      0.040933
# close_log_diff_2_CL=F          0.044121
# close_log_diff_2_EUR=X         0.045543
# close_log_error_63_SEK=X       0.046515
# close_log_diff_1_EUR=X         0.046869
# close_log_diff_1_SEK=X         0.048014
# close_log_diff_1_^OMX          0.048557
# close_log_diff_2_SEK=X         0.061184
# close_log_diff_1_CL=F          0.062600
# close_log_ZB=F                 0.082509
# Name: value_^DJI, dtype: float64

# %%
# check DJI and OMX
for i in range(2):
  name = df.columns[-1-i]
  print('Start check stock ' + name)
  data = df[:-253].sample(frac=1).values
  X, y = data[:, 1:-len(stock_list)], data[:, -1-i]
  model = XGBRegressor()
  cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
  scores = absolute(scores)
  print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))
# Out:
# Start check stock value_^OMX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-896-ec5a86b52da0> in <module>
#       7   model = XGBRegressor()
#       8   cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# ----> 9   scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
#      10   scores = absolute(scores)
#      11   print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
len(df.columns)
# Out:
# 51

# %%
rootdir = '../data/fred'
fred_list = []
for subdir, dirs, files in os.walk(rootdir):
  for dir in files:
    name = dir
    fred_list.append(name)

# %%
fred_list
# Out:
# ['GDP', 'M1SL', 'M2', 'CPI', 'UNRATE']

# %%
def load_fred(name):
  path = '../data/fred'
  df = pd.read_csv(os.path.join(path, name)).dropna()
  df['time']=pd.to_datetime(df['DATE'])
  df['data']=df.iloc[:, 1]
  df['log']=np.log(df['data'])
  df['log_diff']=df['log'].diff()
  return df.replace([np.inf, -np.inf], np.nan).dropna().iloc[:, 2:]

# %%
for i in range(len(fred_list)):
  name = fred_list[i]
  print('merging fred data:' + name)
  df1 = load_fred(name)
  df1 = df1.dropna()

  df1 = rename_dataframe(df1[['time', 'data','log', 'log_diff']], name)
  df = pd.merge_asof(df, df1, on='time')
# Out:
# merging fred data:GDP
# merging fred data:M1SL
# merging fred data:M2
# merging fred data:CPI
# merging fred data:UNRATE
# /home/ken/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/ken/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.iloc[:,-20:].head()
# Out:
#    close_log_diff_SEK=X  close_log_diff_1_SEK=X  close_log_diff_2_SEK=X  \
# 0             -0.006376                0.001429               -0.003905
# 1             -0.010290               -0.006376                0.001429
# 2              0.006412               -0.010290               -0.006376
# 3             -0.006595                0.006412               -0.010290
# 4              0.011199               -0.006595                0.006412
#
#    value_^DJI  value_^OMX   data_GDP   log_GDP  log_diff_GDP  data_M1SL  \
# 0    0.001675   -0.004926  16068.824  9.684636        0.0142     2209.8
# 1    0.003635    0.003347  16068.824  9.684636        0.0142     2209.8
# 2    0.001572   -0.005902  16068.824  9.684636        0.0142     2209.8
# 3    0.005554   -0.007570  16068.824  9.684636        0.0142     2209.8
# 4    0.003954   -0.014480  16068.824  9.684636        0.0142     2232.4
#
#    log_M1SL  log_diff_M1SL  data_M2    log_M2  log_diff_M2  data_CPI  \
# 0  7.700657       0.005536   9789.0  9.189015    -0.000031  0.440297
# 1  7.700657       0.005536   9774.4  9.187522    -0.001493  0.440297
# 2  7.700657       0.005536   9774.4  9.187522    -0.001493  0.440297
# 3  7.700657       0.005536   9774.4  9.187522    -0.001493  0.440297
# 4  7.710833       0.010175   9774.4  9.187522    -0.001493  0.759456
#
#     log_CPI  log_diff_CPI  data_UNRATE  log_UNRATE  log_diff_UNRATE
# 0 -0.820305      0.000632          8.3    2.116256         0.000000
# 1 -0.820305      0.000632          8.3    2.116256         0.000000
# 2 -0.820305      0.000632          8.3    2.116256         0.000000
# 3 -0.820305      0.000632          8.3    2.116256         0.000000
# 4 -0.275153      0.545152          8.2    2.104134        -0.012121

# %%
df.columns
# Out:
# Index(['time', 'close_log_^DJI', 'close_log_error_63_^DJI',
#        'close_log_error_253_^DJI', 'close_log_diff_^DJI',
#        'close_log_diff_1_^DJI', 'close_log_diff_2_^DJI', 'open_log_diff_^DJI',
#        'low_log_diff_^DJI', 'high_log_diff_^DJI', 'close_log_^OMX',
#        'close_log_error_63_^OMX', 'close_log_error_253_^OMX',
#        'close_log_diff_^OMX', 'close_log_diff_1_^OMX', 'close_log_diff_2_^OMX',
#        'open_log_diff_^OMX', 'low_log_diff_^OMX', 'high_log_diff_^OMX',
#        'close_log_EURSEK=X', 'close_log_error_63_EURSEK=X',
#        'close_log_diff_EURSEK=X', 'close_log_diff_1_EURSEK=X',
#        'close_log_diff_2_EURSEK=X', 'close_log_CL=F',
#        'close_log_error_63_CL=F', 'close_log_diff_CL=F',
#        'close_log_diff_1_CL=F', 'close_log_diff_2_CL=F', 'close_log_EUR=X',
#        'close_log_error_63_EUR=X', 'close_log_diff_EUR=X',
#        'close_log_diff_1_EUR=X', 'close_log_diff_2_EUR=X', 'close_log_ZB=F',
#        'close_log_error_63_ZB=F', 'close_log_diff_ZB=F',
#        'close_log_diff_1_ZB=F', 'close_log_diff_2_ZB=F', 'close_log_GC=F',
#        'close_log_error_63_GC=F', 'close_log_diff_GC=F',
#        'close_log_diff_1_GC=F', 'close_log_diff_2_GC=F', 'close_log_SEK=X',
#        'close_log_error_63_SEK=X', 'close_log_diff_SEK=X',
#        'close_log_diff_1_SEK=X', 'close_log_diff_2_SEK=X', 'value_^DJI',
#        'value_^OMX', 'data_GDP', 'log_GDP', 'log_diff_GDP', 'data_M1SL',
#        'log_M1SL', 'log_diff_M1SL', 'data_M2', 'log_M2', 'log_diff_M2',
#        'data_CPI', 'log_CPI', 'log_diff_CPI', 'data_UNRATE', 'log_UNRATE',
#        'log_diff_UNRATE'],
#       dtype='object')

# %%
df = reorder(df)

# %%
df.columns
# Out:
# Index(['time', 'close_log_^DJI', 'close_log_error_63_^DJI',
#        'close_log_error_253_^DJI', 'close_log_diff_^DJI',
#        'close_log_diff_1_^DJI', 'close_log_diff_2_^DJI', 'open_log_diff_^DJI',
#        'low_log_diff_^DJI', 'high_log_diff_^DJI', 'close_log_^OMX',
#        'close_log_error_63_^OMX', 'close_log_error_253_^OMX',
#        'close_log_diff_^OMX', 'close_log_diff_1_^OMX', 'close_log_diff_2_^OMX',
#        'open_log_diff_^OMX', 'low_log_diff_^OMX', 'high_log_diff_^OMX',
#        'close_log_EURSEK=X', 'close_log_error_63_EURSEK=X',
#        'close_log_diff_EURSEK=X', 'close_log_diff_1_EURSEK=X',
#        'close_log_diff_2_EURSEK=X', 'close_log_CL=F',
#        'close_log_error_63_CL=F', 'close_log_diff_CL=F',
#        'close_log_diff_1_CL=F', 'close_log_diff_2_CL=F', 'close_log_EUR=X',
#        'close_log_error_63_EUR=X', 'close_log_diff_EUR=X',
#        'close_log_diff_1_EUR=X', 'close_log_diff_2_EUR=X', 'close_log_ZB=F',
#        'close_log_error_63_ZB=F', 'close_log_diff_ZB=F',
#        'close_log_diff_1_ZB=F', 'close_log_diff_2_ZB=F', 'close_log_GC=F',
#        'close_log_error_63_GC=F', 'close_log_diff_GC=F',
#        'close_log_diff_1_GC=F', 'close_log_diff_2_GC=F', 'close_log_SEK=X',
#        'close_log_error_63_SEK=X', 'close_log_diff_SEK=X',
#        'close_log_diff_1_SEK=X', 'close_log_diff_2_SEK=X', 'data_GDP',
#        'log_GDP', 'log_diff_GDP', 'data_M1SL', 'log_M1SL', 'log_diff_M1SL',
#        'data_M2', 'log_M2', 'log_diff_M2', 'data_CPI', 'log_CPI',
#        'log_diff_CPI', 'data_UNRATE', 'log_UNRATE', 'log_diff_UNRATE',
#        'value_^DJI', 'value_^OMX'],
#       dtype='object')

# %%
pd.options.display.max_rows = 4000
print(df.corr().iloc[:-len(stock_list), -2].sort_values())
# Out:
# close_log_error_63_^DJI       -0.148634
# close_log_error_63_GC=F       -0.122817
# close_log_error_253_^DJI      -0.115408
# close_log_CL=F                -0.088852
# close_log_^OMX                -0.076062
# close_log_error_253_^OMX      -0.061517
# close_log_^DJI                -0.060554
# low_log_diff_^DJI             -0.059797
# close_log_diff_^DJI           -0.053047
# open_log_diff_^OMX            -0.051980
# low_log_diff_^OMX             -0.048083
# close_log_diff_2_^DJI         -0.040380
# data_GDP                      -0.029534
# log_GDP                       -0.026804
# log_diff_GDP                  -0.023388
# open_log_diff_^DJI            -0.020439
# close_log_EUR=X               -0.020054
# close_log_diff_1_ZB=F         -0.018529
# close_log_diff_2_GC=F         -0.014688
# close_log_SEK=X               -0.012656
# close_log_diff_2_ZB=F         -0.006098
# close_log_diff_^OMX           -0.004162
# high_log_diff_^OMX            -0.001308
# close_log_EURSEK=X            -0.001024
# close_log_diff_2_^OMX          0.006048
# close_log_error_63_CL=F        0.006197
# close_log_diff_ZB=F            0.007702
# high_log_diff_^DJI             0.009614
# close_log_diff_EURSEK=X        0.011497
# close_log_diff_1_GC=F          0.018313
# close_log_error_63_EURSEK=X    0.024685
# data_M2                        0.025389
# log_M2                         0.025451
# close_log_error_63_ZB=F        0.026780
# close_log_diff_EUR=X           0.027533
# close_log_diff_1_^DJI          0.029345
# close_log_error_63_^OMX        0.029422
# close_log_diff_GC=F            0.031997
# close_log_diff_1_EURSEK=X      0.035178
# close_log_diff_CL=F            0.036518
# close_log_diff_SEK=X           0.037315
# close_log_error_63_EUR=X       0.039400
# close_log_GC=F                 0.040658
# close_log_diff_2_EURSEK=X      0.040933
# close_log_diff_2_CL=F          0.044121
# close_log_diff_2_EUR=X         0.045543
# close_log_error_63_SEK=X       0.046515
# close_log_diff_1_EUR=X         0.046869
# close_log_diff_1_SEK=X         0.048014
# close_log_diff_1_^OMX          0.048557
# log_diff_UNRATE                0.050393
# log_CPI                        0.052658
# data_M1SL                      0.056015
# log_diff_CPI                   0.056870
# log_M1SL                       0.056907
# close_log_diff_2_SEK=X         0.061184
# data_CPI                       0.061646
# close_log_diff_1_CL=F          0.062600
# log_diff_M2                    0.078590
# close_log_ZB=F                 0.082509
# log_diff_M1SL                  0.143577
# log_UNRATE                     0.148144
# data_UNRATE                    0.157805
# Name: value_^DJI, dtype: float64

# %%
# check DJI and OMX
for i in range(2):
  name = df.columns[-1-i]
  print('Start check stock ' + name)
  data = df[:-253].sample(frac=1).values
  X, y = data[:, 1:-len(stock_list)], data[:, -1-i]
  model = XGBRegressor()
  cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
  scores = absolute(scores)
  print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))
# Out:
# Start check stock value_^OMX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-ec5a86b52da0> in <module>
#       7   model = XGBRegressor()
#       8   cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# ----> 9   scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
#      10   scores = absolute(scores)
#      11   print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     507     scorer = check_scoring(estimator, scoring=scoring)
#     508
# --> 509     cv_results = cross_validate(
#     510         estimator=estimator,
#     511         X=X,
#
# ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     265     # independent, and that it is pickle-able.
#     266     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267     results = parallel(
#     268         delayed(_fit_and_score)(
#     269             clone(estimator),
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                     return self.__get_result()
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#     441                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
model_dji = XGBRegressor()
data = df[:-253].sample(frac=1).values
data_test = df[-253:].values
X, y = data[:, 1:-len(stock_list)], data[:, -2]
X_test, y_test = data_test[:, 1:-len(stock_list)], data_test[:, -2]
model_dji.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = model_dji.predict(X_test)

# %%
y_pred.shape
# Out:
# (253,)

# %%
df_new = pd.DataFrame({'y_pred': y_pred, 'y': y_test, 'close_log_^DJI': df[-253:]['close_log_^DJI'], 'time': data_test[:, 0]})

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
ax0 = df_new.plot(ax=axes[0], x='time', y=['y_pred','y'])
xtick = pd.date_range( start=df_new['time'].min(), end=df_new['time'].max(), freq='W' )
axes[0].set_xticks(xtick, minor=True)
axes[0].grid('on', which='minor', axis='x')
axes[0].grid('off', which='major', axis='x')
y_start = int(min(df_new['y_pred'].min(), df_new['y'].min()) * 100)
y_end   = int(max(df_new['y'].max(), df_new['y'].max()) * 100)

axes[0].set_yticks([item * 0.01 for item in range(y_start, y_end)], minor=True)
axes[0].grid('on', which='minor', axis='y')
axes[0].grid('off', which='major', axis='y')
df[-253:].plot(ax=axes[1], x='time', y='close_log_^DJI')
axes[1].set_xticks(xtick, minor=True)
axes[1].grid('on', which='minor', axis='x')
axes[1].grid('off', which='major', axis='x')

#axes[0].grid('on', which='minor', axis='x' )

# %%
df.tail()
# Out:
#                     time  close_log_^DJI  close_log_error_63_^DJI  \
# 2510 2022-02-14 14:30:00       10.450631                -0.078606
# 2511 2022-02-15 14:30:00       10.462784                -0.066937
# 2512 2022-02-16 14:30:00       10.461224                -0.068983
# 2513 2022-02-17 14:30:00       10.443251                -0.087440
# 2514 2022-02-18 17:58:18       10.434962                -0.096285
#
#       close_log_error_253_^DJI  close_log_diff_^DJI  close_log_diff_1_^DJI  \
# 2510                 -0.286967            -0.004960              -0.014391
# 2511                 -0.275816             0.012154              -0.004960
# 2512                 -0.278379            -0.001561               0.012154
# 2513                 -0.297354            -0.017972              -0.001561
# 2514                 -0.306791            -0.008289              -0.017972
#
#       close_log_diff_2_^DJI  open_log_diff_^DJI  low_log_diff_^DJI  \
# 2510              -0.014828           -0.001255          -0.012566
# 2511              -0.014391            0.003466           0.003466
# 2512              -0.004960           -0.001058          -0.009944
# 2513               0.012154           -0.002172          -0.019892
# 2514              -0.001561           -0.000046          -0.008755
#
#       high_log_diff_^DJI  ...    log_M2  log_diff_M2  data_CPI   log_CPI  \
# 2510            0.000187  ...  9.991714    -0.001226  0.307252 -1.180088
# 2511            0.013837  ...  9.991714    -0.001226  0.307252 -1.180088
# 2512            0.001521  ...  9.991714    -0.001226  0.307252 -1.180088
# 2513           -0.002172  ...  9.991714    -0.001226  0.307252 -1.180088
# 2514            0.003246  ...  9.991714    -0.001226  0.307252 -1.180088
#
#       log_diff_CPI  data_UNRATE  log_UNRATE  log_diff_UNRATE  value_^DJI  \
# 2510     -0.469475          3.9    1.360977        -0.074108   -0.009852
# 2511     -0.469475          3.9    1.360977        -0.074108   -0.024450
# 2512     -0.469475          3.9    1.360977        -0.074108   -0.025433
# 2513     -0.469475          3.9    1.360977        -0.074108   -0.008289
# 2514     -0.469475          3.9    1.360977        -0.074108    0.000000
#
#       value_^OMX
# 2510   -0.011923
# 2511   -0.033436
# 2512   -0.028033
# 2513   -0.014201
# 2514    0.000000
#
# [5 rows x 66 columns]

# %%
profit = 0
state = 0
close_log_diff = df['close_log_diff_^DJI'][-253:]
low_log_diff = df['low_log_diff_^DJI'][-253:]
open_log_diff = df['open_log_diff_^DJI'][-253:]
security = 0
loss_stop = -0.04
hold_days = 0
security_list = []
profit_list = []
bid_times = 0
bid_loss_stop = 0
for i in range(len(y_pred)):
  
  security += close_log_diff.iloc[i]
  if state == 1:
    hold_days += 1
    change = close_log_diff.iloc[i]
    low_diff = low_log_diff.iloc[i]
    open_diff = open_log_diff.iloc[i]
    if low_diff < loss_stop:
      change = min(loss_stop, open_diff)
      state = 0
      profit += change
      security_list.append(security)
      profit_list.append(profit)
      bid_times += 1
      bid_loss_stop += 1
      
      continue
    else:
      profit += change
  if y_pred[i] > 0.03 and state == 0:
    state = 1
    bid_times += 1
  elif y_pred[i] <= 0.01 and state == 1:
    state = 0
    bid_times += 1
  security_list.append(security)
  profit_list.append(profit)

print(profit)
print(security)
print(hold_days)
print('bid_times=',bid_times, 'loss_stops=', bid_loss_stop)
print(len(security_list))
print(len(profit_list))
print(len(y_pred))
# Out:
# 0.11621388073907646
# 0.07739945184927421
# 223
# bid_times= 5 loss_stops= 0
# 253
# 253
# 253

# %%
df_new['security_list']=security_list
df_new['profit_list']=profit_list
df_new.plot(x='time', y=['security_list', 'profit_list'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
model_omx = XGBRegressor()
data_test = df[-253:].values
X, y = data[:, 1:-len(stock_list)], data[:, -1]
X_test, y_test = data_test[:, 1:-len(stock_list)], data_test[:, -1]
model_omx.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = model_omx.predict(X_test)
df_new = pd.DataFrame({'y_pred': y_pred, 'y': y_test, 'close_log_^OMX': df[-253:]['close_log_^OMX'], 'time': data_test[:, 0]})

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
ax0 = df_new.plot(ax=axes[0], x='time', y=['y_pred','y'])
xtick = pd.date_range( start=df_new['time'].min(), end=df_new['time'].max(), freq='W' )
axes[0].set_xticks(xtick, minor=True)
axes[0].grid('on', which='minor', axis='x')
axes[0].grid('off', which='major', axis='x')
y_start = int(min(df_new['y_pred'].min(), df_new['y'].min()) * 100)
y_end   = int(max(df_new['y'].max(), df_new['y'].max()) * 100)

axes[0].set_yticks([item * 0.01 for item in range(y_start, y_end)], minor=True)
axes[0].grid('on', which='minor', axis='y')
axes[0].grid('off', which='major', axis='y')
df[-253:].plot(ax=axes[1], x='time', y='close_log_^DJI')
axes[1].set_xticks(xtick, minor=True)
axes[1].grid('on', which='minor', axis='x')
axes[1].grid('off', which='major', axis='x')

# %%
import json
import re



def loadScbData(scbData):
  name = scbData['name']
  time_index = scbData['time_index']
  value_index = scbData['value_index']
  f = open('../data/scb/' + name)
  data = json.load(f)
  f.close()
  
  def toMonth(a):
    match = re.search("([0-9]{4})M([0-9]{2})", a[time_index])
    return match.group(1) + match.group(2)

  df1 = pd.read_json(json.dumps(data['data']))
  df1['month'] = df1['key'].apply(toMonth)
  df1['time']=pd.to_datetime(df1['month'], format='%Y%m')
  df1['data'] = df1['values'].apply(lambda x: float(x[value_index]))
  df1['data_log'] = np.log(df1['data'])
  df1['data_log_diff'] = df1['data_log'].diff()
  df1 = df1.dropna()
  df1 = rename_dataframe(df1[['time', 'data', 'data_log', 'data_log_diff']], name)
  return df1

# %%
scb_data_list = [{
    'name': 'm1',
    'time_index': 1,
    'value_index': 0
  }, {
    'name': 'm3',
    'time_index': 1,
    'value_index': 0
  }, {
    'name': 'cpi',
    'time_index': 0,
    'value_index': 1
  }
]

for scb_data in scb_data_list:
  print(scb_data)
  print('Adding ' + scb_data['name'])
  df1 = loadScbData(scb_data)
  df = pd.merge_asof(df, df1, on='time')
# Out:
# {'name': 'm1', 'time_index': 1, 'value_index': 0}
# Adding m1
# {'name': 'm3', 'time_index': 1, 'value_index': 0}
# Adding m3
# {'name': 'cpi', 'time_index': 0, 'value_index': 1}
# Adding cpi

# %%
df = reorder(df)

# %%
df.head()
# Out:
#                  time  close_log_^DJI  close_log_error_63_^DJI  \
# 0 2012-02-24 14:30:00        9.471392                      0.0
# 1 2012-02-27 14:30:00        9.471281                      0.0
# 2 2012-02-28 14:30:00        9.473098                      0.0
# 3 2012-02-29 14:30:00        9.469011                      0.0
# 4 2012-03-01 14:30:00        9.471188                      0.0
#
#    close_log_error_253_^DJI  close_log_diff_^DJI  close_log_diff_1_^DJI  \
# 0                       0.0            -0.000134               0.003551
# 1                       0.0            -0.000111              -0.000134
# 2                       0.0             0.001817              -0.000111
# 3                       0.0            -0.004087               0.001817
# 4                       0.0             0.002177              -0.004087
#
#    close_log_diff_2_^DJI  open_log_diff_^DJI  low_log_diff_^DJI  \
# 0              -0.002086           -0.000269          -0.002630
# 1               0.003551           -0.000140          -0.007760
# 2              -0.000134           -0.000367          -0.002212
# 3              -0.000111            0.000023          -0.005819
# 4               0.001817            0.000017          -0.000696
#
#    high_log_diff_^DJI  ...  data_log_m1  data_log_diff_m1    data_m3  \
# 0            0.002241  ...    14.278345         -0.016695  2366737.0
# 1            0.003427  ...    14.278345         -0.016695  2366737.0
# 2            0.003077  ...    14.278345         -0.016695  2366737.0
# 3            0.003886  ...    14.278345         -0.016695  2366737.0
# 4            0.006204  ...    14.282935          0.004590  2374874.0
#
#    data_log_m3  data_log_diff_m3  data_cpi  data_log_cpi  data_log_diff_cpi  \
# 0    14.677023         -0.011872    313.92      5.749138           0.006616
# 1    14.677023         -0.011872    313.92      5.749138           0.006616
# 2    14.677023         -0.011872    313.92      5.749138           0.006616
# 3    14.677023         -0.011872    313.92      5.749138           0.006616
# 4    14.680455          0.003432    314.80      5.751938           0.002799
#
#    value_^DJI  value_^OMX
# 0    0.001675   -0.004926
# 1    0.003635    0.003347
# 2    0.001572   -0.005902
# 3    0.005554   -0.007570
# 4    0.003954   -0.014480
#
# [5 rows x 75 columns]

# %%
# check DJI and OMX
for i in range(2):
  name = df.columns[-1-i]
  print('Start check stock ' + name)
  data = df[:-253].sample(frac=1).values
  X, y = data[:, 1:-len(stock_list)], data[:, -1-i]
  model = XGBRegressor()
  cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
  scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
  scores = absolute(scores)
  print('Mean MAE: %.4f (%.4f)' % (scores.mean(), scores.std()))
# Out:
# Start check stock value_^OMX
# Mean MAE: 0.0076 (0.0005)
# Start check stock value_^DJI
# Mean MAE: 0.0063 (0.0006)

# %%
scores
# Out:
# array([0.00754793, 0.00751677, 0.00654866, 0.00741697, 0.00709828,
#        0.00757491, 0.00695814, 0.00764097, 0.0070172 , 0.00687084,
#        0.00734826, 0.00689969, 0.00832105, 0.00790597, 0.00686411,
#        0.00635945, 0.00635014, 0.00728448, 0.00761762, 0.00755848,
#        0.00645437, 0.00681979, 0.00656733, 0.00826157, 0.00674195,
#        0.00755364, 0.0069382 , 0.00738765, 0.00633216, 0.00660739])

# %%
df.corr().iloc[:,-1].sort_values()
# Out:
# close_log_error_63_^DJI       -0.126157
# close_log_^OMX                -0.083295
# low_log_diff_^OMX             -0.078760
# close_log_CL=F                -0.067314
# close_log_error_253_^DJI      -0.065982
# open_log_diff_^OMX            -0.054777
# close_log_EUR=X               -0.053335
# data_log_diff_cpi             -0.050260
# log_diff_GDP                  -0.049074
# close_log_error_63_CL=F       -0.047645
# low_log_diff_^DJI             -0.041078
# close_log_diff_^OMX           -0.039733
# close_log_error_63_EUR=X      -0.037635
# close_log_diff_2_^DJI         -0.034081
# close_log_^DJI                -0.029134
# close_log_diff_1_^DJI         -0.028012
# close_log_error_63_GC=F       -0.026292
# close_log_diff_1_^OMX         -0.022521
# close_log_error_253_^OMX      -0.020705
# close_log_SEK=X               -0.020094
# close_log_error_63_SEK=X      -0.013054
# data_GDP                      -0.011706
# open_log_diff_^DJI            -0.011358
# log_GDP                       -0.010582
# close_log_diff_2_GC=F         -0.005634
# close_log_diff_ZB=F           -0.002475
# close_log_diff_2_^OMX         -0.000667
# close_log_diff_1_CL=F          0.005253
# high_log_diff_^OMX             0.005534
# data_log_diff_m1               0.007817
# data_log_diff_m3               0.008225
# close_log_diff_2_CL=F          0.009560
# close_log_diff_1_ZB=F          0.012359
# close_log_error_63_^OMX        0.012982
# close_log_diff_CL=F            0.013362
# data_cpi                       0.014389
# data_log_cpi                   0.014639
# close_log_diff_2_ZB=F          0.015068
# close_log_diff_1_GC=F          0.017365
# close_log_diff_GC=F            0.018257
# close_log_EURSEK=X             0.019307
# data_log_m1                    0.023905
# close_log_error_63_EURSEK=X    0.024563
# data_log_m3                    0.028674
# data_m1                        0.030410
# data_m3                        0.033124
# close_log_diff_EURSEK=X        0.033503
# log_diff_UNRATE                0.034598
# close_log_diff_2_EURSEK=X      0.037083
# close_log_diff_1_EURSEK=X      0.039051
# close_log_diff_EUR=X           0.039544
# close_log_error_63_ZB=F        0.040067
# log_M2                         0.041983
# close_log_diff_2_EUR=X         0.043203
# data_M2                        0.044049
# close_log_diff_^DJI            0.044268
# close_log_diff_2_SEK=X         0.053088
# close_log_diff_1_EUR=X         0.054684
# high_log_diff_^DJI             0.060781
# close_log_diff_SEK=X           0.062097
# close_log_diff_1_SEK=X         0.062765
# data_CPI                       0.064563
# log_M1SL                       0.079021
# data_M1SL                      0.079106
# close_log_ZB=F                 0.081226
# log_CPI                        0.082392
# log_diff_M2                    0.090846
# close_log_GC=F                 0.097640
# log_diff_CPI                   0.109703
# log_diff_M1SL                  0.127399
# log_UNRATE                     0.156014
# data_UNRATE                    0.160248
# value_^DJI                     0.774928
# value_^OMX                     1.000000
# Name: value_^OMX, dtype: float64

# %%
model_omx = XGBRegressor()
data_test = df[-253:].values
X, y = data[:, 1:-len(stock_list)], data[:, -1]
X_test, y_test = data_test[:, 1:-len(stock_list)], data_test[:, -1]
model_omx.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred = model_omx.predict(X_test)
df_new = pd.DataFrame({'y_pred': y_pred, 'y': y_test, 'close_log_^OMX': df[-253:]['close_log_^OMX'], 'time': data_test[:, 0]})

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
ax0 = df_new.plot(ax=axes[0], x='time', y=['y_pred','y'])
xtick = pd.date_range( start=df_new['time'].min(), end=df_new['time'].max(), freq='W' )
axes[0].set_xticks(xtick, minor=True)
axes[0].grid('on', which='minor', axis='x')
axes[0].grid('off', which='major', axis='x')
y_start = int(min(df_new['y_pred'].min(), df_new['y'].min()) * 100)
y_end   = int(max(df_new['y'].max(), df_new['y'].max()) * 100)

axes[0].set_yticks([item * 0.01 for item in range(y_start, y_end)], minor=True)
axes[0].grid('on', which='minor', axis='y')
axes[0].grid('off', which='major', axis='y')
df[-253:].plot(ax=axes[1], x='time', y='close_log_^DJI')
axes[1].set_xticks(xtick, minor=True)
axes[1].grid('on', which='minor', axis='x')
axes[1].grid('off', which='major', axis='x')

# %%
profit = 0
state = 0
close_log_diff = df['close_log_diff_^OMX'][-253:]
low_log_diff = df['low_log_diff_^OMX'][-253:]
open_log_diff = df['open_log_diff_^OMX'][-253:]
security = 0
loss_stop = -0.001
hold_days = 0
security_list = []
profit_list = []
bid_times = 0
bid_loss_stop = 0
for i in range(len(y_pred)):
  
  security += close_log_diff.iloc[i]
  if state == 1:
    hold_days += 1
    change = close_log_diff.iloc[i]
    low_diff = low_log_diff.iloc[i]
    open_diff = open_log_diff.iloc[i]
    if low_diff < loss_stop:
      change = min(loss_stop, open_diff)
      state = 0
      profit += change
      security_list.append(security)
      profit_list.append(profit)
      bid_times += 1
      bid_loss_stop += 1
      
      continue
    else:
      profit += change
  if y_pred[i] > 0.05 and state == 0:
    state = 1
    bid_times += 1
  elif y_pred[i] <= 0.04 and state == 1:
    state = 0
    bid_times += 1
  security_list.append(security)
  profit_list.append(profit)

print(profit)
print(security)
print(hold_days)
print('bid_times=',bid_times, 'loss_stops=', bid_loss_stop)
print(len(security_list))
print(len(profit_list))
print(len(y_pred))
# Out:
# 0.024122142890435683
# 0.08313679696618959
# 4
# bid_times= 6 loss_stops= 2
# 253
# 253
# 253
