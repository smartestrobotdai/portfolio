# %%
source('./util.r')

df <- data_prep_multiple(c("EVO.ST","ELUX-B.ST"), HHt_val=0.08, GGt_val=0.08, isNYSE=FALSE)
process_multiple(df, 0.7, 0.05, -0.01, 0.00069)
# Out:
# [1] FALSE FALSE FALSE FALSE FALSE FALSE
# [1] "ELUX.B.ST"
#            EVO.ST.open EVO.ST.high EVO.ST.low EVO.ST.close EVO.ST.volume
# 2007-01-02          NA          NA         NA           NA            NA
#            EVO.ST.adjusted EVO.ST.last_close EVO.ST.no_model_profit EVO.ST.mean
# 2007-01-02              NA                NA                     NA          NA
#            EVO.ST.predict ELUX.B.ST.open ELUX.B.ST.high ELUX.B.ST.low
# 2007-01-02             NA       4.919981        4.93087      4.903421
#            ELUX.B.ST.close ELUX.B.ST.volume ELUX.B.ST.adjusted
# 2007-01-02        4.916325         14.53603           4.218417
#            ELUX.B.ST.last_close ELUX.B.ST.no_model_profit ELUX.B.ST.mean
# 2007-01-02             4.919981                         0       4.917146
#            ELUX.B.ST.predict
# 2007-01-02          4.917146
# [1] FALSE FALSE FALSE FALSE FALSE FALSE
# [1] "ELUX.B.ST"
#            EVO.ST.open EVO.ST.high EVO.ST.low EVO.ST.close EVO.ST.volume
# ...

# %%
paste(head(strsplit("aaaaa.bb", split=".", fixed=T)[[1]], -1), collapse='.')
# Out:
# [1] "aaaaa"

# %%
remove_colname_suffix <- function(name) {
  paste(head(strsplit(name, split=".", fixed=T)[[1]], -1), collapse='.')
}

m_l <- c('aaa.cc', 'ccc.bb')
lapply(m_l, remove_colname_suffix)
# Out:
# [[1]]
# [1] "aaa"
#
# [[2]]
# [1] "ccc"

# %%
df <- data_prep('SHB-A.ST', isNYSE=FALSE)

# %%
df %>% filter(is.na(close))
# Out:
#      open high low close volume adjusted last_close no_model_profit

# %%
df %>% filter(rownames(df) > '2007-10-30' & rownames(df) < '2007-11-08')
# Out:
#            open     high     low      close    volume   adjusted last_close
# 2007-10-31 4.241327 4.253246 4.234107 4.250873 16.37552 3.697788 4.241327
# 2007-11-01 4.250873 4.253246 4.219508 4.236519 16.01558 3.683434 4.250873
# 2007-11-05 4.207177 4.217054 4.194693 4.204693 16.37934 3.651607 4.236519
# 2007-11-06 4.207177 4.212128 4.189655 4.197202 16.06806 3.644116 4.204693
# 2007-11-07 4.197202 4.202202 4.166665 4.179502 16.32272 3.626417 4.197202
#            no_model_profit
# 2007-10-31  0.009546574
# 2007-11-01 -0.014354314
# 2007-11-05 -0.031826393
# 2007-11-06 -0.007490672
# 2007-11-07 -0.017699536

# %%
df %>% filter(rownames(df) > '2007-10-30' & rownames(df) < '2007-11-08')
# Out:
#   open     high     low      close    volume   adjusted last_close
# 1 4.241327 4.253246 4.234107 4.250873 16.37552 3.697788 4.241327
# 2 4.250873 4.253246 4.219508 4.236519 16.01558 3.683434 4.250873
# 3 4.229025 4.235150 4.207100 4.220606 16.19746 3.667520 4.236519
# 4 4.207177 4.217054 4.194693 4.204693 16.37934 3.651607 4.220606
# 5 4.207177 4.212128 4.189655 4.197202 16.06806 3.644116 4.204693
# 6 4.197202 4.202202 4.166665 4.179502 16.32272 3.626417 4.197202
#   no_model_profit
# 1  0.009546574
# 2 -0.014354314
# 3 -0.012066433
# 4 -0.009778552
# 5 -0.007490672
# 6 -0.017699536
